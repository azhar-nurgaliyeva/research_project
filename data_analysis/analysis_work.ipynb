# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# 2018 leakages
df_leakages_2018 = pd.read_csv('C:/Users/aznur/PycharmProjects/research_project/data_analysis/2018_Leakages.csv', decimal=',', sep=';',
                          index_col='Timestamp')
# 2019 leakages
df_leakages_2019 = pd.read_csv('C:/Users/aznur/PycharmProjects/research_project/data_analysis/2019_Leakages.csv', decimal=',', sep=';',
                          index_col='Timestamp')

# Dataframe with both 2018 and 2019 leakages
result = pd.concat([df_leakages_2018, df_leakages_2019], axis=0)
result = result.fillna(0)

# 2018 pressure from sensors
df_pressures = pd.read_csv('C:/Users/aznur/PycharmProjects/research_project/data_analysis/2018_SCADA_Pressures.csv', decimal=',',
                           sep=';', index_col='Timestamp')
# 2018 flows
df_flows = pd.read_csv('C:/Users/aznur/PycharmProjects/research_project/data_analysis/2018_SCADA_Flows.csv', decimal=',',
                           sep=';', index_col='Timestamp')
# 2018 demand values
df_demands = pd.read_csv('C:/Users/aznur/PycharmProjects/research_project/data_analysis/2018_SCADA_Demands.csv', decimal=',',
                           sep=';', index_col='Timestamp')

# %%
df_columns_pressures = list(df_pressures.columns.values)
columns_new = []

for i in df_columns_pressures:
    if i in list(df_demands.columns.values):
        columns_new.insert(len(columns_new)+1, i)

df_columns_pressures = columns_new
df_demands_new = df_demands[df_columns_pressures[0:3]]
df_pressures_new = df_pressures[df_columns_pressures]

# %%
# df_leakages_2018.to_excel("2018.xlsx", sheet_name='leakages')

# %%
# df_leakages_2019.to_excel("2019.xlsx", sheet_name='leakages')

# %%
# fig = plt.figure(figsize=(16,8),dpi=300)
# result.plot(ax=plt.gca())
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper right', borderaxespad=0)
# plt.title('Combined timeline for leakages in 2018 and 2019')
# plt.xlabel('Date (YYYY-MM-DD HH:MM:SS)')
# plt.ylabel('Flow ($m^3$/h)')
# plt.savefig('C:/Users/aznur/PycharmProjects/research_project/data_analysis/analysis/2018_and_2019_leakages.png')
# plt.show()

# %%
# fig = plt.figure(figsize=(16,8),dpi=300)
# df_pressures.plot(ax=plt.gca())
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper right', borderaxespad=0)
# plt.title('Pressure measurements from sensors in 2018')
# plt.xlabel('Date (YYYY-MM-DD HH:MM:SS)')
# plt.ylabel('Pressure (m)')
# plt.savefig('C:/Users/aznur/PycharmProjects/research_project/data_analysis/analysis/2018_pressures.png')
# plt.show()

# %%
# fig = plt.figure(figsize=(16,8), dpi=300)
# df_demands.plot(ax=plt.gca())
# plt.legend(loc='upper right', borderaxespad=0, borderpad=1)
# plt.title('Water flow demand measurements in 2018')
# plt.xlabel('Date (YYYY-MM-DD HH:MM:SS)')
# plt.ylabel('Flow (L/h)')
# plt.savefig('C:/Users/aznur/PycharmProjects/research_project/data_analysis/analysis/2018_demands.png')
# plt.show()

# %%
# fig = plt.figure(figsize=(16,8),dpi=300)
# df_flows.plot(ax=plt.gca())
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper right', borderaxespad=0)
# plt.title('Flow measurements from sensors in 2018')
# plt.xlabel('Date (YYYY-MM-DD HH:MM:SS)')
# plt.ylabel('Flow ($m^3$/h)')
# plt.savefig('C:/Users/aznur/PycharmProjects/research_project/data_analysis/analysis/2018_flows.png')
# plt.show()

# %%
# 2019 pressure from sensors
df_pressures_2019 = pd.read_csv('C:/Users/aznur/PycharmProjects/research_project/data_analysis/2019_SCADA_Pressures.csv', decimal=',',
                           sep=';', index_col='Timestamp')

# %%
# 2019 demand values
df_demands_2019 = pd.read_csv('C:/Users/aznur/PycharmProjects/research_project/data_analysis/2019_SCADA_Demands.csv', decimal=',',
                           sep=';', index_col='Timestamp')
df_demands_new_2019 = df_demands_2019[df_columns_pressures[0:3]]

# Dataframe with both 2018 and 2019 demands
result_demand = pd.concat([df_demands_new, df_demands_new_2019], axis=0)
result_demand = result_demand.fillna(0)
print(result_demand)
# Out:
#                          n1       n4     n31
# Timestamp
# 2018-01-01 00:00:00   40.83   131.29   99.56
# 2018-01-01 00:05:00   40.20   136.21   69.52
# 2018-01-01 00:10:00   38.06   131.00   81.71
# 2018-01-01 00:15:00   37.24   155.02   33.78
# 2018-01-01 00:20:00   45.38   148.66  128.59
# ...                     ...      ...     ...
# 2019-12-31 23:35:00  117.46  1929.92   72.05
# 2019-12-31 23:40:00  119.47  2042.10   33.03
# 2019-12-31 23:45:00  203.61  2044.56  101.30
# 2019-12-31 23:50:00  204.87  1993.61   62.71
# 2019-12-31 23:55:00  225.63  1967.27   76.86
#
# [210240 rows x 3 columns]

# %%
fig = plt.figure(figsize=(16,8),dpi=300)
df_31 = result_demand[['n31']]
df_31.plot(ax=plt.gca())
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper right', borderaxespad=0)
plt.title('Water demand flow for n31 between 2018 and 2019')
plt.xlabel('Date (YYYY-MM-DD HH:MM:SS)')
plt.ylabel('Flow (L/h)')
plt.savefig('C:/Users/aznur/PycharmProjects/research_project/data_analysis/analysis/demand_differences.png')
plt.show()

# %%
fig = plt.figure(figsize=(16,8),dpi=300)
df_4 = result_demand[['n4']]
df_4.plot(ax=plt.gca())
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper right', borderaxespad=0)
plt.title('Water demand flow for n4 between 2018 and 2019')
plt.xlabel('Date (YYYY-MM-DD HH:MM:SS)')
plt.ylabel('Flow (L/h)')
plt.savefig('C:/Users/aznur/PycharmProjects/research_project/data_analysis/analysis/demand_differences1.png')
plt.show()

# %%
fig = plt.figure(figsize=(16,8),dpi=300)
df_p_31 = result[['p31']]
df_p_31.plot(ax=plt.gca())
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper right', borderaxespad=0)
plt.title('Leakage in p31 in 2018 and 2019')
plt.xlabel('Date (YYYY-MM-DD HH:MM:SS)')
plt.ylabel('Flow ($m^3$/h)')
plt.savefig('C:/Users/aznur/PycharmProjects/research_project/data_analysis/analysis/pressure31.png')
plt.show()
